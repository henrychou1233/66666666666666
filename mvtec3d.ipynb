# %%
import os
import shutil
from PIL import Image

def process_and_copy_images_quantize(source_dir, target_dir, num_colors=64):
    """
    遞迴遍歷原始目錄及其子目錄中的影像，複製到目標目錄並進行顏色量化處理（減少顏色數量），
    同時在目標目錄中維持相同的子資料夾結構。

    Args:
        source_dir (str): 原始影像的根目錄路徑。
        target_dir (str): 目標影像的根目錄路徑。
        num_colors (int): 影像將被量化成的最大顏色數量 (例如 16, 64, 128)。
    """
    print(f"--- 開始處理，目標：將影像顏色數量減少到 {num_colors} 種 ---")
    
    # 確保目標根目錄存在，如果不存在則創建
    if not os.path.exists(target_dir):
        os.makedirs(target_dir)
        print(f"✅ 已創建目標根目錄: {target_dir}")
    else:
        print(f"ℹ️ 目標根目錄已存在: {target_dir}")

    # 支援的影像檔案擴展名
    supported_extensions = ('.jpg', '.jpeg', '.png', '.bmp', '.tiff')
    processed_count = 0
    
    # 使用 os.walk() 遞迴遍歷資料夾結構
    for root, dirs, files in os.walk(source_dir):
        # 計算當前目錄相對於原始根目錄的路徑部分
        relative_path = os.path.relpath(root, source_dir)
        
        # 構建目標目錄中的對應路徑
        current_target_dir = os.path.join(target_dir, relative_path)
        
        # 如果目標子目錄不存在，則創建它
        if not os.path.exists(current_target_dir):
            os.makedirs(current_target_dir)
            
        # 遍歷當前目錄下的所有檔案
        for filename in files:
            # 檢查是否為支援的影像類型
            if filename.lower().endswith(supported_extensions):
                source_path = os.path.join(root, filename)
                target_path = os.path.join(current_target_dir, filename)

                try:
                    # 1. 開啟影像
                    img = Image.open(source_path)
                    
                    # 2. 進行影像處理：顏色量化 (Quantization)
                    # 使用 img.quantize() 方法將影像的顏色數量限制為 num_colors
                    quantized_img = img.quantize(colors=num_colors)
                    
                    # 3. 儲存處理後的影像到目標子目錄
                    # 注意：量化後的影像通常應該儲存為 PNG 格式以保留顏色資訊，
                    # 但為了維持檔案名，我們仍使用原始檔名，由 Pillow 決定最佳格式。
                    quantized_img.save(target_path)
                    
                    processed_count += 1
                    # 輸出相對路徑讓訊息更簡潔
                    print(f"➡️ 已處理並儲存: {os.path.join(relative_path, filename)}")
                    
                except Exception as e:
                    print(f"❌ 處理檔案 {source_path} 時發生錯誤: {e}")
                
    print(f"\n✨ 處理完成！總共處理了 {processed_count} 個影像檔案。")


# --- 設定目錄路徑 ---
SOURCE_DIRECTORY = r"C:\Users\anywhere4090\Desktop\henry\dataset\newmvtec3d\peach"
TARGET_DIRECTORY = r"C:\Users\anywhere4090\Desktop\henry\dataset\newmvtec3d\cpeach"
# 設定顏色數量，例如 64 色，您可以根據需要更改這個值（例如 16, 128, 256）
NUM_TARGET_COLORS =8

# --- 執行處理函式 ---
if __name__ == "__main__":
    process_and_copy_images_quantize(SOURCE_DIRECTORY, TARGET_DIRECTORY, NUM_TARGET_COLORS)
# Out:
# --- 開始處理，目標：將影像顏色數量減少到 8 種 ---
# ℹ️ 目標根目錄已存在: C:\Users\anywhere4090\Desktop\henry\dataset\newmvtec3d\cpeach
# ➡️ 已處理並儲存: ground_truth\combined\000.png
# ➡️ 已處理並儲存: ground_truth\combined\001.png
# ➡️ 已處理並儲存: ground_truth\combined\002.png
# ➡️ 已處理並儲存: ground_truth\combined\003.png
# ➡️ 已處理並儲存: ground_truth\combined\004.png
# ➡️ 已處理並儲存: ground_truth\combined\005.png
# ➡️ 已處理並儲存: ground_truth\combined\006.png
# ➡️ 已處理並儲存: ground_truth\combined\007.png
# ➡️ 已處理並儲存: ground_truth\combined\008.png
# ➡️ 已處理並儲存: ground_truth\combined\009.png
# ➡️ 已處理並儲存: ground_truth\combined\010.png
# ➡️ 已處理並儲存: ground_truth\combined\011.png
# ➡️ 已處理並儲存: ground_truth\combined\012.png
# ➡️ 已處理並儲存: ground_truth\combined\013.png
# ➡️ 已處理並儲存: ground_truth\combined\014.png
# ➡️ 已處理並儲存: ground_truth\combined\015.png
# ➡️ 已處理並儲存: ground_truth\combined\016.png
# ➡️ 已處理並儲存: ground_truth\combined\017.png
# ➡️ 已處理並儲存: ground_truth\combined\018.png
# ➡️ 已處理並儲存: ground_truth\combined\019.png
# ➡️ 已處理並儲存: ground_truth\combined\020.png
# ➡️ 已處理並儲存: ground_truth\combined\021.png
# ➡️ 已處理並儲存: ground_truth\combined\022.png
# ➡️ 已處理並儲存: ground_truth\combined\023.png
# ➡️ 已處理並儲存: ground_truth\combined\024.png
# ➡️ 已處理並儲存: ground_truth\contamination\000.png
# ➡️ 已處理並儲存: ground_truth\contamination\001.png
# ➡️ 已處理並儲存: ground_truth\contamination\002.png
# ➡️ 已處理並儲存: ground_truth\contamination\003.png
# ➡️ 已處理並儲存: ground_truth\contamination\004.png
# ➡️ 已處理並儲存: ground_truth\contamination\005.png
# ➡️ 已處理並儲存: ground_truth\contamination\006.png
# ➡️ 已處理並儲存: ground_truth\contamination\007.png
# ➡️ 已處理並儲存: ground_truth\contamination\008.png
# ➡️ 已處理並儲存: ground_truth\contamination\009.png
# ➡️ 已處理並儲存: ground_truth\contamination\010.png
# ➡️ 已處理並儲存: ground_truth\contamination\011.png
# ➡️ 已處理並儲存: ground_truth\contamination\012.png
# ➡️ 已處理並儲存: ground_truth\contamination\013.png
# ➡️ 已處理並儲存: ground_truth\contamination\014.png
# ➡️ 已處理並儲存: ground_truth\contamination\015.png
# ➡️ 已處理並儲存: ground_truth\contamination\016.png
# ➡️ 已處理並儲存: ground_truth\contamination\017.png
# ➡️ 已處理並儲存: ground_truth\contamination\018.png
# ➡️ 已處理並儲存: ground_truth\contamination\019.png
# ➡️ 已處理並儲存: ground_truth\contamination\020.png
# ➡️ 已處理並儲存: ground_truth\contamination\021.png
# ➡️ 已處理並儲存: ground_truth\contamination\022.png
# ➡️ 已處理並儲存: ground_truth\contamination\023.png
# ➡️ 已處理並儲存: ground_truth\contamination\024.png
# ➡️ 已處理並儲存: ground_truth\contamination\025.png
# ➡️ 已處理並儲存: ground_truth\contamination\026.png
# ➡️ 已處理並儲存: ground_truth\cut\000.png
# ➡️ 已處理並儲存: ground_truth\cut\001.png
# ➡️ 已處理並儲存: ground_truth\cut\002.png
# ➡️ 已處理並儲存: ground_truth\cut\003.png
# ➡️ 已處理並儲存: ground_truth\cut\004.png
# ➡️ 已處理並儲存: ground_truth\cut\005.png
# ➡️ 已處理並儲存: ground_truth\cut\006.png
# ➡️ 已處理並儲存: ground_truth\cut\007.png
# ➡️ 已處理並儲存: ground_truth\cut\008.png
# ➡️ 已處理並儲存: ground_truth\cut\009.png
# ➡️ 已處理並儲存: ground_truth\cut\010.png
# ➡️ 已處理並儲存: ground_truth\cut\011.png
# ➡️ 已處理並儲存: ground_truth\cut\012.png
# ➡️ 已處理並儲存: ground_truth\cut\013.png
# ➡️ 已處理並儲存: ground_truth\cut\014.png
# ➡️ 已處理並儲存: ground_truth\cut\015.png
# ➡️ 已處理並儲存: ground_truth\cut\016.png
# ➡️ 已處理並儲存: ground_truth\cut\017.png
# ➡️ 已處理並儲存: ground_truth\cut\018.png
# ➡️ 已處理並儲存: ground_truth\cut\019.png
# ➡️ 已處理並儲存: ground_truth\cut\020.png
# ➡️ 已處理並儲存: ground_truth\cut\021.png
# ➡️ 已處理並儲存: ground_truth\cut\022.png
# ➡️ 已處理並儲存: ground_truth\cut\023.png
# ➡️ 已處理並儲存: ground_truth\cut\024.png
# ➡️ 已處理並儲存: ground_truth\good\000.png
# ➡️ 已處理並儲存: ground_truth\good\001.png
# ➡️ 已處理並儲存: ground_truth\good\002.png
# ➡️ 已處理並儲存: ground_truth\good\003.png
# ➡️ 已處理並儲存: ground_truth\good\004.png
# ➡️ 已處理並儲存: ground_truth\good\005.png
# ➡️ 已處理並儲存: ground_truth\good\006.png
# ➡️ 已處理並儲存: ground_truth\good\007.png
# ➡️ 已處理並儲存: ground_truth\good\008.png
# ➡️ 已處理並儲存: ground_truth\good\009.png
# ➡️ 已處理並儲存: ground_truth\good\010.png
# ➡️ 已處理並儲存: ground_truth\good\011.png
# ➡️ 已處理並儲存: ground_truth\good\012.png
# ➡️ 已處理並儲存: ground_truth\good\013.png
# ➡️ 已處理並儲存: ground_truth\good\014.png
# ➡️ 已處理並儲存: ground_truth\good\015.png
# ➡️ 已處理並儲存: ground_truth\good\016.png
# ➡️ 已處理並儲存: ground_truth\good\017.png
# ➡️ 已處理並儲存: ground_truth\good\018.png
# ➡️ 已處理並儲存: ground_truth\good\019.png
# ➡️ 已處理並儲存: ground_truth\good\020.png
# ➡️ 已處理並儲存: ground_truth\good\021.png
# ➡️ 已處理並儲存: ground_truth\good\022.png
# ➡️ 已處理並儲存: ground_truth\good\023.png
# ➡️ 已處理並儲存: ground_truth\good\024.png
# ➡️ 已處理並儲存: ground_truth\good\025.png
# ➡️ 已處理並儲存: ground_truth\hole\000.png
# ➡️ 已處理並儲存: ground_truth\hole\001.png
# ➡️ 已處理並儲存: ground_truth\hole\002.png
# ➡️ 已處理並儲存: ground_truth\hole\003.png
# ➡️ 已處理並儲存: ground_truth\hole\004.png
# ➡️ 已處理並儲存: ground_truth\hole\005.png
# ➡️ 已處理並儲存: ground_truth\hole\006.png
# ➡️ 已處理並儲存: ground_truth\hole\007.png
# ➡️ 已處理並儲存: ground_truth\hole\008.png
# ➡️ 已處理並儲存: ground_truth\hole\009.png
# ➡️ 已處理並儲存: ground_truth\hole\010.png
# ➡️ 已處理並儲存: ground_truth\hole\011.png
# ➡️ 已處理並儲存: ground_truth\hole\012.png
# ➡️ 已處理並儲存: ground_truth\hole\013.png
# ➡️ 已處理並儲存: ground_truth\hole\014.png
# ➡️ 已處理並儲存: ground_truth\hole\015.png
# ➡️ 已處理並儲存: ground_truth\hole\016.png
# ➡️ 已處理並儲存: ground_truth\hole\017.png
# ➡️ 已處理並儲存: ground_truth\hole\018.png
# ➡️ 已處理並儲存: ground_truth\hole\019.png
# ➡️ 已處理並儲存: ground_truth\hole\020.png
# ➡️ 已處理並儲存: ground_truth\hole\021.png
# ➡️ 已處理並儲存: ground_truth\hole\022.png
# ➡️ 已處理並儲存: ground_truth\hole\023.png
# ➡️ 已處理並儲存: ground_truth\hole\024.png
# ➡️ 已處理並儲存: ground_truth\hole\025.png
# ➡️ 已處理並儲存: ground_truth\hole\026.png
# ➡️ 已處理並儲存: ground_truth\hole\027.png
# ➡️ 已處理並儲存: ground_truth\hole\028.png
# ➡️ 已處理並儲存: test\combined\000.png
# ➡️ 已處理並儲存: test\combined\001.png
# ➡️ 已處理並儲存: test\combined\002.png
# ➡️ 已處理並儲存: test\combined\003.png
# ➡️ 已處理並儲存: test\combined\004.png
# ➡️ 已處理並儲存: test\combined\005.png
# ➡️ 已處理並儲存: test\combined\006.png
# ➡️ 已處理並儲存: test\combined\007.png
# ➡️ 已處理並儲存: test\combined\008.png
# ➡️ 已處理並儲存: test\combined\009.png
# ➡️ 已處理並儲存: test\combined\010.png
# ➡️ 已處理並儲存: test\combined\011.png
# ➡️ 已處理並儲存: test\combined\012.png
# ➡️ 已處理並儲存: test\combined\013.png
# ➡️ 已處理並儲存: test\combined\014.png
# ➡️ 已處理並儲存: test\combined\015.png
# ➡️ 已處理並儲存: test\combined\016.png
# ➡️ 已處理並儲存: test\combined\017.png
# ➡️ 已處理並儲存: test\combined\018.png
# ➡️ 已處理並儲存: test\combined\019.png
# ➡️ 已處理並儲存: test\combined\020.png
# ➡️ 已處理並儲存: test\combined\021.png
# ➡️ 已處理並儲存: test\combined\022.png
# ➡️ 已處理並儲存: test\combined\023.png
# ➡️ 已處理並儲存: test\combined\024.png
# ➡️ 已處理並儲存: test\contamination\000.png
# ➡️ 已處理並儲存: test\contamination\001.png
# ➡️ 已處理並儲存: test\contamination\002.png
# ➡️ 已處理並儲存: test\contamination\003.png
# ➡️ 已處理並儲存: test\contamination\004.png
# ➡️ 已處理並儲存: test\contamination\005.png
# ➡️ 已處理並儲存: test\contamination\006.png
# ➡️ 已處理並儲存: test\contamination\007.png
# ➡️ 已處理並儲存: test\contamination\008.png
# ➡️ 已處理並儲存: test\contamination\009.png
# ➡️ 已處理並儲存: test\contamination\010.png
# ➡️ 已處理並儲存: test\contamination\011.png
# ➡️ 已處理並儲存: test\contamination\012.png
# ➡️ 已處理並儲存: test\contamination\013.png
# ➡️ 已處理並儲存: test\contamination\014.png
# ➡️ 已處理並儲存: test\contamination\015.png
# ➡️ 已處理並儲存: test\contamination\016.png
# ➡️ 已處理並儲存: test\contamination\017.png
# ➡️ 已處理並儲存: test\contamination\018.png
# ➡️ 已處理並儲存: test\contamination\019.png
# ➡️ 已處理並儲存: test\contamination\020.png
# ➡️ 已處理並儲存: test\contamination\021.png
# ➡️ 已處理並儲存: test\contamination\022.png
# ➡️ 已處理並儲存: test\contamination\023.png
# ➡️ 已處理並儲存: test\contamination\024.png
# ➡️ 已處理並儲存: test\contamination\025.png
# ➡️ 已處理並儲存: test\contamination\026.png
# ➡️ 已處理並儲存: test\cut\000.png
# ➡️ 已處理並儲存: test\cut\001.png
# ➡️ 已處理並儲存: test\cut\002.png
# ➡️ 已處理並儲存: test\cut\003.png
# ➡️ 已處理並儲存: test\cut\004.png
# ➡️ 已處理並儲存: test\cut\005.png
# ➡️ 已處理並儲存: test\cut\006.png
# ➡️ 已處理並儲存: test\cut\007.png
# ➡️ 已處理並儲存: test\cut\008.png
# ➡️ 已處理並儲存: test\cut\009.png
# ➡️ 已處理並儲存: test\cut\010.png
# ➡️ 已處理並儲存: test\cut\011.png
# ➡️ 已處理並儲存: test\cut\012.png
# ➡️ 已處理並儲存: test\cut\013.png
# ➡️ 已處理並儲存: test\cut\014.png
# ➡️ 已處理並儲存: test\cut\015.png
# ➡️ 已處理並儲存: test\cut\016.png
# ➡️ 已處理並儲存: test\cut\017.png
# ➡️ 已處理並儲存: test\cut\018.png
# ➡️ 已處理並儲存: test\cut\019.png
# ➡️ 已處理並儲存: test\cut\020.png
# ➡️ 已處理並儲存: test\cut\021.png
# ➡️ 已處理並儲存: test\cut\022.png
# ➡️ 已處理並儲存: test\cut\023.png
# ➡️ 已處理並儲存: test\cut\024.png
# ➡️ 已處理並儲存: test\good\000.png
# ➡️ 已處理並儲存: test\good\001.png
# ➡️ 已處理並儲存: test\good\002.png
# ➡️ 已處理並儲存: test\good\003.png
# ➡️ 已處理並儲存: test\good\004.png
# ➡️ 已處理並儲存: test\good\005.png
# ➡️ 已處理並儲存: test\good\006.png
# ➡️ 已處理並儲存: test\good\007.png
# ➡️ 已處理並儲存: test\good\008.png
# ➡️ 已處理並儲存: test\good\009.png
# ➡️ 已處理並儲存: test\good\010.png
# ➡️ 已處理並儲存: test\good\011.png
# ➡️ 已處理並儲存: test\good\012.png
# ➡️ 已處理並儲存: test\good\013.png
# ➡️ 已處理並儲存: test\good\014.png
# ➡️ 已處理並儲存: test\good\015.png
# ➡️ 已處理並儲存: test\good\016.png
# ➡️ 已處理並儲存: test\good\017.png
# ➡️ 已處理並儲存: test\good\018.png
# ➡️ 已處理並儲存: test\good\019.png
# ➡️ 已處理並儲存: test\good\020.png
# ➡️ 已處理並儲存: test\good\021.png
# ➡️ 已處理並儲存: test\good\022.png
# ➡️ 已處理並儲存: test\good\023.png
# ➡️ 已處理並儲存: test\good\024.png
# ➡️ 已處理並儲存: test\good\025.png
# ➡️ 已處理並儲存: test\hole\000.png
# ➡️ 已處理並儲存: test\hole\001.png
# ➡️ 已處理並儲存: test\hole\002.png
# ➡️ 已處理並儲存: test\hole\003.png
# ➡️ 已處理並儲存: test\hole\004.png
# ➡️ 已處理並儲存: test\hole\005.png
# ➡️ 已處理並儲存: test\hole\006.png
# ➡️ 已處理並儲存: test\hole\007.png
# ➡️ 已處理並儲存: test\hole\008.png
# ➡️ 已處理並儲存: test\hole\009.png
# ➡️ 已處理並儲存: test\hole\010.png
# ➡️ 已處理並儲存: test\hole\011.png
# ➡️ 已處理並儲存: test\hole\012.png
# ➡️ 已處理並儲存: test\hole\013.png
# ➡️ 已處理並儲存: test\hole\014.png
# ➡️ 已處理並儲存: test\hole\015.png
# ➡️ 已處理並儲存: test\hole\016.png
# ➡️ 已處理並儲存: test\hole\017.png
# ➡️ 已處理並儲存: test\hole\018.png
# ➡️ 已處理並儲存: test\hole\019.png
# ➡️ 已處理並儲存: test\hole\020.png
# ➡️ 已處理並儲存: test\hole\021.png
# ➡️ 已處理並儲存: test\hole\022.png
# ➡️ 已處理並儲存: test\hole\023.png
# ➡️ 已處理並儲存: test\hole\024.png
# ➡️ 已處理並儲存: test\hole\025.png
# ➡️ 已處理並儲存: test\hole\026.png
# ➡️ 已處理並儲存: test\hole\027.png
# ➡️ 已處理並儲存: test\hole\028.png
# ➡️ 已處理並儲存: train\good\000.png
# ➡️ 已處理並儲存: train\good\001.png
# ➡️ 已處理並儲存: train\good\002.png
# ➡️ 已處理並儲存: train\good\003.png
# ➡️ 已處理並儲存: train\good\004.png
# ➡️ 已處理並儲存: train\good\005.png
# ➡️ 已處理並儲存: train\good\006.png
# ➡️ 已處理並儲存: train\good\007.png
# ➡️ 已處理並儲存: train\good\008.png
# ➡️ 已處理並儲存: train\good\009.png
# ➡️ 已處理並儲存: train\good\010.png
# ➡️ 已處理並儲存: train\good\011.png
# ➡️ 已處理並儲存: train\good\012.png
# ➡️ 已處理並儲存: train\good\013.png
# ➡️ 已處理並儲存: train\good\014.png
# ➡️ 已處理並儲存: train\good\015.png
# ➡️ 已處理並儲存: train\good\016.png
# ➡️ 已處理並儲存: train\good\017.png
# ➡️ 已處理並儲存: train\good\018.png
# ➡️ 已處理並儲存: train\good\019.png
# ➡️ 已處理並儲存: train\good\020.png
# ➡️ 已處理並儲存: train\good\021.png
# ➡️ 已處理並儲存: train\good\022.png
# ➡️ 已處理並儲存: train\good\023.png
# ➡️ 已處理並儲存: train\good\024.png
# ➡️ 已處理並儲存: train\good\025.png
# ➡️ 已處理並儲存: train\good\026.png
# ➡️ 已處理並儲存: train\good\027.png
# ➡️ 已處理並儲存: train\good\028.png
# ➡️ 已處理並儲存: train\good\029.png
# ➡️ 已處理並儲存: train\good\030.png
# ➡️ 已處理並儲存: train\good\031.png
# ➡️ 已處理並儲存: train\good\032.png
# ➡️ 已處理並儲存: train\good\033.png
# ➡️ 已處理並儲存: train\good\034.png
# ➡️ 已處理並儲存: train\good\035.png
# ➡️ 已處理並儲存: train\good\036.png
# ➡️ 已處理並儲存: train\good\037.png
# ➡️ 已處理並儲存: train\good\038.png
# ➡️ 已處理並儲存: train\good\039.png
# ➡️ 已處理並儲存: train\good\040.png
# ➡️ 已處理並儲存: train\good\041.png
# ➡️ 已處理並儲存: train\good\042.png
# ➡️ 已處理並儲存: train\good\043.png
# ➡️ 已處理並儲存: train\good\044.png
# ➡️ 已處理並儲存: train\good\045.png
# ➡️ 已處理並儲存: train\good\046.png
# ➡️ 已處理並儲存: train\good\047.png
# ➡️ 已處理並儲存: train\good\048.png
# ➡️ 已處理並儲存: train\good\049.png
# ➡️ 已處理並儲存: train\good\050.png
# ➡️ 已處理並儲存: train\good\051.png
# ➡️ 已處理並儲存: train\good\052.png
# ➡️ 已處理並儲存: train\good\053.png
# ➡️ 已處理並儲存: train\good\054.png
# ➡️ 已處理並儲存: train\good\055.png
# ➡️ 已處理並儲存: train\good\056.png
# ➡️ 已處理並儲存: train\good\057.png
# ➡️ 已處理並儲存: train\good\058.png
# ➡️ 已處理並儲存: train\good\059.png
# ➡️ 已處理並儲存: train\good\060.png
# ➡️ 已處理並儲存: train\good\061.png
# ➡️ 已處理並儲存: train\good\062.png
# ➡️ 已處理並儲存: train\good\063.png
# ➡️ 已處理並儲存: train\good\064.png
# ➡️ 已處理並儲存: train\good\065.png
# ➡️ 已處理並儲存: train\good\066.png
# ➡️ 已處理並儲存: train\good\067.png
# ➡️ 已處理並儲存: train\good\068.png
# ➡️ 已處理並儲存: train\good\069.png
# ➡️ 已處理並儲存: train\good\070.png
# ➡️ 已處理並儲存: train\good\071.png
# ➡️ 已處理並儲存: train\good\072.png
# ➡️ 已處理並儲存: train\good\073.png
# ➡️ 已處理並儲存: train\good\074.png
# ➡️ 已處理並儲存: train\good\075.png
# ➡️ 已處理並儲存: train\good\076.png
# ➡️ 已處理並儲存: train\good\077.png
# ➡️ 已處理並儲存: train\good\078.png
# ➡️ 已處理並儲存: train\good\079.png
# ➡️ 已處理並儲存: train\good\080.png
# ➡️ 已處理並儲存: train\good\081.png
# ➡️ 已處理並儲存: train\good\082.png
# ➡️ 已處理並儲存: train\good\083.png
# ➡️ 已處理並儲存: train\good\084.png
# ➡️ 已處理並儲存: train\good\085.png
# ➡️ 已處理並儲存: train\good\086.png
# ➡️ 已處理並儲存: train\good\087.png
# ➡️ 已處理並儲存: train\good\088.png
# ➡️ 已處理並儲存: train\good\089.png
# ➡️ 已處理並儲存: train\good\090.png
# ➡️ 已處理並儲存: train\good\091.png
# ➡️ 已處理並儲存: train\good\092.png
# ➡️ 已處理並儲存: train\good\093.png
# ➡️ 已處理並儲存: train\good\094.png
# ➡️ 已處理並儲存: train\good\095.png
# ➡️ 已處理並儲存: train\good\096.png
# ➡️ 已處理並儲存: train\good\097.png
# ➡️ 已處理並儲存: train\good\098.png
# ➡️ 已處理並儲存: train\good\099.png
# ➡️ 已處理並儲存: train\good\100.png
# ➡️ 已處理並儲存: train\good\101.png
# ➡️ 已處理並儲存: train\good\102.png
# ➡️ 已處理並儲存: train\good\103.png
# ➡️ 已處理並儲存: train\good\104.png
# ➡️ 已處理並儲存: train\good\105.png
# ➡️ 已處理並儲存: train\good\106.png
# ➡️ 已處理並儲存: train\good\107.png
# ➡️ 已處理並儲存: train\good\108.png
# ➡️ 已處理並儲存: train\good\109.png
# ➡️ 已處理並儲存: train\good\110.png
# ➡️ 已處理並儲存: train\good\111.png
# ➡️ 已處理並儲存: train\good\112.png
# ➡️ 已處理並儲存: train\good\113.png
# ➡️ 已處理並儲存: train\good\114.png
# ➡️ 已處理並儲存: train\good\115.png
# ➡️ 已處理並儲存: train\good\116.png
# ➡️ 已處理並儲存: train\good\117.png
# ➡️ 已處理並儲存: train\good\118.png
# ➡️ 已處理並儲存: train\good\119.png
# ➡️ 已處理並儲存: train\good\120.png
# ➡️ 已處理並儲存: train\good\121.png
# ➡️ 已處理並儲存: train\good\122.png
# ➡️ 已處理並儲存: train\good\123.png
# ➡️ 已處理並儲存: train\good\124.png
# ➡️ 已處理並儲存: train\good\125.png
# ➡️ 已處理並儲存: train\good\126.png
# ➡️ 已處理並儲存: train\good\127.png
# ➡️ 已處理並儲存: train\good\128.png
# ➡️ 已處理並儲存: train\good\129.png
# ➡️ 已處理並儲存: train\good\130.png
# ➡️ 已處理並儲存: train\good\131.png
# ➡️ 已處理並儲存: train\good\132.png
# ➡️ 已處理並儲存: train\good\133.png
# ➡️ 已處理並儲存: train\good\134.png
# ➡️ 已處理並儲存: train\good\135.png
# ➡️ 已處理並儲存: train\good\136.png
# ➡️ 已處理並儲存: train\good\137.png
# ➡️ 已處理並儲存: train\good\138.png
# ➡️ 已處理並儲存: train\good\139.png
# ➡️ 已處理並儲存: train\good\140.png
# ➡️ 已處理並儲存: train\good\141.png
# ➡️ 已處理並儲存: train\good\142.png
# ➡️ 已處理並儲存: train\good\143.png
# ➡️ 已處理並儲存: train\good\144.png
# ➡️ 已處理並儲存: train\good\145.png
# ➡️ 已處理並儲存: train\good\146.png
# ➡️ 已處理並儲存: train\good\147.png
# ➡️ 已處理並儲存: train\good\148.png
# ➡️ 已處理並儲存: train\good\149.png
# ➡️ 已處理並儲存: train\good\150.png
# ➡️ 已處理並儲存: train\good\151.png
# ➡️ 已處理並儲存: train\good\152.png
# ➡️ 已處理並儲存: train\good\153.png
# ➡️ 已處理並儲存: train\good\154.png
# ➡️ 已處理並儲存: train\good\155.png
# ➡️ 已處理並儲存: train\good\156.png
# ➡️ 已處理並儲存: train\good\157.png
# ➡️ 已處理並儲存: train\good\158.png
# ➡️ 已處理並儲存: train\good\159.png
# ➡️ 已處理並儲存: train\good\160.png
# ➡️ 已處理並儲存: train\good\161.png
# ➡️ 已處理並儲存: train\good\162.png
# ➡️ 已處理並儲存: train\good\163.png
# ➡️ 已處理並儲存: train\good\164.png
# ➡️ 已處理並儲存: train\good\165.png
# ➡️ 已處理並儲存: train\good\166.png
# ➡️ 已處理並儲存: train\good\167.png
# ➡️ 已處理並儲存: train\good\168.png
# ➡️ 已處理並儲存: train\good\169.png
# ➡️ 已處理並儲存: train\good\170.png
# ➡️ 已處理並儲存: train\good\171.png
# ➡️ 已處理並儲存: train\good\172.png
# ➡️ 已處理並儲存: train\good\173.png
# ➡️ 已處理並儲存: train\good\174.png
# ➡️ 已處理並儲存: train\good\175.png
# ➡️ 已處理並儲存: train\good\176.png
# ➡️ 已處理並儲存: train\good\177.png
# ➡️ 已處理並儲存: train\good\178.png
# ➡️ 已處理並儲存: train\good\179.png
# ➡️ 已處理並儲存: train\good\180.png
# ➡️ 已處理並儲存: train\good\181.png
# ➡️ 已處理並儲存: train\good\182.png
# ➡️ 已處理並儲存: train\good\183.png
# ➡️ 已處理並儲存: train\good\184.png
# ➡️ 已處理並儲存: train\good\185.png
# ➡️ 已處理並儲存: train\good\186.png
# ➡️ 已處理並儲存: train\good\187.png
# ➡️ 已處理並儲存: train\good\188.png
# ➡️ 已處理並儲存: train\good\189.png
# ➡️ 已處理並儲存: train\good\190.png
# ➡️ 已處理並儲存: train\good\191.png
# ➡️ 已處理並儲存: train\good\192.png
# ➡️ 已處理並儲存: train\good\193.png
# ➡️ 已處理並儲存: train\good\194.png
# ➡️ 已處理並儲存: train\good\195.png
# ➡️ 已處理並儲存: train\good\196.png
# ➡️ 已處理並儲存: train\good\197.png
# ➡️ 已處理並儲存: train\good\198.png
# ➡️ 已處理並儲存: train\good\199.png
# ➡️ 已處理並儲存: train\good\200.png
# ➡️ 已處理並儲存: train\good\201.png
# ➡️ 已處理並儲存: train\good\202.png
# ➡️ 已處理並儲存: train\good\203.png
# ➡️ 已處理並儲存: train\good\204.png
# ➡️ 已處理並儲存: train\good\205.png
# ➡️ 已處理並儲存: train\good\206.png
# ➡️ 已處理並儲存: train\good\207.png
# ➡️ 已處理並儲存: train\good\208.png
# ➡️ 已處理並儲存: train\good\209.png
# ➡️ 已處理並儲存: train\good\210.png
# ➡️ 已處理並儲存: train\good\211.png
# ➡️ 已處理並儲存: train\good\212.png
# ➡️ 已處理並儲存: train\good\213.png
# ➡️ 已處理並儲存: train\good\214.png
# ➡️ 已處理並儲存: train\good\215.png
# ➡️ 已處理並儲存: train\good\216.png
# ➡️ 已處理並儲存: train\good\217.png
# ➡️ 已處理並儲存: train\good\218.png
# ➡️ 已處理並儲存: train\good\219.png
# ➡️ 已處理並儲存: train\good\220.png
# ➡️ 已處理並儲存: train\good\221.png
# ➡️ 已處理並儲存: train\good\222.png
# ➡️ 已處理並儲存: train\good\223.png
# ➡️ 已處理並儲存: train\good\224.png
# ➡️ 已處理並儲存: train\good\225.png
# ➡️ 已處理並儲存: train\good\226.png
# ➡️ 已處理並儲存: train\good\227.png
# ➡️ 已處理並儲存: train\good\228.png
# ➡️ 已處理並儲存: train\good\229.png
# ➡️ 已處理並儲存: train\good\230.png
# ➡️ 已處理並儲存: train\good\231.png
# ➡️ 已處理並儲存: train\good\232.png
# ➡️ 已處理並儲存: train\good\233.png
# ➡️ 已處理並儲存: train\good\234.png
# ➡️ 已處理並儲存: train\good\235.png
# ➡️ 已處理並儲存: train\good\236.png
# ➡️ 已處理並儲存: train\good\237.png
# ➡️ 已處理並儲存: train\good\238.png
# ➡️ 已處理並儲存: train\good\239.png
# ➡️ 已處理並儲存: train\good\240.png
# ➡️ 已處理並儲存: train\good\241.png
# ➡️ 已處理並儲存: train\good\242.png
# ➡️ 已處理並儲存: train\good\243.png
# ➡️ 已處理並儲存: train\good\244.png
# ➡️ 已處理並儲存: train\good\245.png
# ➡️ 已處理並儲存: train\good\246.png
# ➡️ 已處理並儲存: train\good\247.png
# ➡️ 已處理並儲存: train\good\248.png
# ➡️ 已處理並儲存: train\good\249.png
# ➡️ 已處理並儲存: train\good\250.png
# ➡️ 已處理並儲存: train\good\251.png
# ➡️ 已處理並儲存: train\good\252.png
# ➡️ 已處理並儲存: train\good\253.png
# ➡️ 已處理並儲存: train\good\254.png
# ➡️ 已處理並儲存: train\good\255.png
# ➡️ 已處理並儲存: train\good\256.png
# ➡️ 已處理並儲存: train\good\257.png
# ➡️ 已處理並儲存: train\good\258.png
# ➡️ 已處理並儲存: train\good\259.png
# ➡️ 已處理並儲存: train\good\260.png
# ➡️ 已處理並儲存: train\good\261.png
# ➡️ 已處理並儲存: train\good\262.png
# ➡️ 已處理並儲存: train\good\263.png
# ➡️ 已處理並儲存: train\good\264.png
# ➡️ 已處理並儲存: train\good\265.png
# ➡️ 已處理並儲存: train\good\266.png
# ➡️ 已處理並儲存: train\good\267.png
# ➡️ 已處理並儲存: train\good\268.png
# ➡️ 已處理並儲存: train\good\269.png
# ➡️ 已處理並儲存: train\good\270.png
# ➡️ 已處理並儲存: train\good\271.png
# ➡️ 已處理並儲存: train\good\272.png
# ➡️ 已處理並儲存: train\good\273.png
# ➡️ 已處理並儲存: train\good\274.png
# ➡️ 已處理並儲存: train\good\275.png
# ➡️ 已處理並儲存: train\good\276.png
# ➡️ 已處理並儲存: train\good\277.png
# ➡️ 已處理並儲存: train\good\278.png
# ➡️ 已處理並儲存: train\good\279.png
# ➡️ 已處理並儲存: train\good\280.png
# ➡️ 已處理並儲存: train\good\281.png
# ➡️ 已處理並儲存: train\good\282.png
# ➡️ 已處理並儲存: train\good\283.png
# ➡️ 已處理並儲存: train\good\284.png
# ➡️ 已處理並儲存: train\good\285.png
# ➡️ 已處理並儲存: train\good\286.png
# ➡️ 已處理並儲存: train\good\287.png
# ➡️ 已處理並儲存: train\good\288.png
# ➡️ 已處理並儲存: train\good\289.png
# ➡️ 已處理並儲存: train\good\290.png
# ➡️ 已處理並儲存: train\good\291.png
# ➡️ 已處理並儲存: train\good\292.png
# ➡️ 已處理並儲存: train\good\293.png
# ➡️ 已處理並儲存: train\good\294.png
# ➡️ 已處理並儲存: train\good\295.png
# ➡️ 已處理並儲存: train\good\296.png
# ➡️ 已處理並儲存: train\good\297.png
# ➡️ 已處理並儲存: train\good\298.png
# ➡️ 已處理並儲存: train\good\299.png
# ➡️ 已處理並儲存: train\good\300.png
# ➡️ 已處理並儲存: train\good\301.png
# ➡️ 已處理並儲存: train\good\302.png
# ➡️ 已處理並儲存: train\good\303.png
# ➡️ 已處理並儲存: train\good\304.png
# ➡️ 已處理並儲存: train\good\305.png
# ➡️ 已處理並儲存: train\good\306.png
# ➡️ 已處理並儲存: train\good\307.png
# ➡️ 已處理並儲存: train\good\308.png
# ➡️ 已處理並儲存: train\good\309.png
# ➡️ 已處理並儲存: train\good\310.png
# ➡️ 已處理並儲存: train\good\311.png
# ➡️ 已處理並儲存: train\good\312.png
# ➡️ 已處理並儲存: train\good\313.png
# ➡️ 已處理並儲存: train\good\314.png
# ➡️ 已處理並儲存: train\good\315.png
# ➡️ 已處理並儲存: train\good\316.png
# ➡️ 已處理並儲存: train\good\317.png
# ➡️ 已處理並儲存: train\good\318.png
# ➡️ 已處理並儲存: train\good\319.png
# ➡️ 已處理並儲存: train\good\320.png
# ➡️ 已處理並儲存: train\good\321.png
# ➡️ 已處理並儲存: train\good\322.png
# ➡️ 已處理並儲存: train\good\323.png
# ➡️ 已處理並儲存: train\good\324.png
# ➡️ 已處理並儲存: train\good\325.png
# ➡️ 已處理並儲存: train\good\326.png
# ➡️ 已處理並儲存: train\good\327.png
# ➡️ 已處理並儲存: train\good\328.png
# ➡️ 已處理並儲存: train\good\329.png
# ➡️ 已處理並儲存: train\good\330.png
# ➡️ 已處理並儲存: train\good\331.png
# ➡️ 已處理並儲存: train\good\332.png
# ➡️ 已處理並儲存: train\good\333.png
# ➡️ 已處理並儲存: train\good\334.png
# ➡️ 已處理並儲存: train\good\335.png
# ➡️ 已處理並儲存: train\good\336.png
# ➡️ 已處理並儲存: train\good\337.png
# ➡️ 已處理並儲存: train\good\338.png
# ➡️ 已處理並儲存: train\good\339.png
# ➡️ 已處理並儲存: train\good\340.png
# ➡️ 已處理並儲存: train\good\341.png
# ➡️ 已處理並儲存: train\good\342.png
# ➡️ 已處理並儲存: train\good\343.png
# ➡️ 已處理並儲存: train\good\344.png
# ➡️ 已處理並儲存: train\good\345.png
# ➡️ 已處理並儲存: train\good\346.png
# ➡️ 已處理並儲存: train\good\347.png
# ➡️ 已處理並儲存: train\good\348.png
# ➡️ 已處理並儲存: train\good\349.png
# ➡️ 已處理並儲存: train\good\350.png
# ➡️ 已處理並儲存: train\good\351.png
# ➡️ 已處理並儲存: train\good\352.png
# ➡️ 已處理並儲存: train\good\353.png
# ➡️ 已處理並儲存: train\good\354.png
# ➡️ 已處理並儲存: train\good\355.png
# ➡️ 已處理並儲存: train\good\356.png
# ➡️ 已處理並儲存: train\good\357.png
# ➡️ 已處理並儲存: train\good\358.png
# ➡️ 已處理並儲存: train\good\359.png
# ➡️ 已處理並儲存: train\good\360.png
#
# ✨ 處理完成！總共處理了 625 個影像檔案。
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.
